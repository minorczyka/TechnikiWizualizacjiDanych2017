# %%
from bs4 import BeautifulSoup
import requests

page01 = requests.get("http://weszlo.com/2017/12/10/paradoks-bjelicy-lech-chorwata-najlepszy-bez-niego-lawce/")
soup = BeautifulSoup(page01.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <!--[if lt IE 7 ]><html class="ie ie6 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]><html class="ie ie7 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]><html class="ie ie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]><html class="ie ie9 no-js" lang="en"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js WpReset" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="823585757711534" property="fb:app_id">
#    <title>
#     Paradoks Bjelicy. Lech Chorwata najlepszy… bez niego na ławce - weszlo.com
#    </title>
#    <link href="//gmpg.org/xfn/11" rel="profile"/>
#    <link href="" rel="pingback"/>
#    <style>
#     /* Custom BSA_PRO Styles */
#
# 	/* fonts */
#
# 	/* form */
# 	.bsaProOrderingForm {   }
# 	.bsaProInput input,
# 	.bsaProInput input[type='file'],
# 	.bsaProSelectSpace select,
# 	.bsaProInputsRight .bsaInputInner,
# ...

# %%
import pandas as pd
test = pd.DataFrame({
        "A": [0,1,2,3,4],
        "B": [5,6,7,8,9]
    })

# %%
test
# Out:
#    A  B
# 0  0  5
# 1  1  6
# 2  2  7
# 3  3  8
# 4  4  9

# %%
test.to_csv("plik.csv", index = False)
